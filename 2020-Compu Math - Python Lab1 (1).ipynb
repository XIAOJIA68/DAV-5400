# %%
import pandas as pd

cdc = pd.read_csv('https://www.openintro.org/stat/data/cdc.csv')
cdc
# Out:
#          genhlth  exerany  hlthplan  smoke100  height  weight  wtdesire  age  \
# 0           good        0         1         0      70     175       175   77
# 1           good        0         1         1      64     125       115   33
# 2           good        1         1         1      60     105       105   49
# 3           good        1         1         0      66     132       124   42
# 4      very good        0         1         0      61     150       130   55
# 5      very good        1         1         0      64     114       114   55
# 6      very good        1         1         0      71     194       185   31
# 7      very good        0         1         0      67     170       160   45
# 8           good        0         1         1      65     150       130   27
# 9           good        1         1         0      70     180       170   44
# 10     excellent        1         1         1      69     186       175   46
# ...

# %% [markdown]
# The data set cdc that shows up is a data matrix, with each row representing a case and each column representing a variable. These kind of data format are called data frame, which is a term that will be used throughout the labs.

# %%
#To view the names of the variables, use columns.values

cdc.columns.values
# Out:
# array(['genhlth', 'exerany', 'hlthplan', 'smoke100', 'height', 'weight',
#        'wtdesire', 'age', 'gender'], dtype=object)

# %% [markdown]
# This returns the names genhlth, exerany, hlthplan, smoke100, height, weight, wtdesire, age, and gender. Each one of these variables corresponds to a question that was asked in the survey. For example, for genhlth, respondents were asked to evaluate their general health, responding either excellent, very good, good, fair or poor. The exerany variable indicates whether the respondent exercised in the past month (1) or did not (0). Likewise, hlthplan indicates whether the respondent had some form of health coverage (1) or did not (0). The smoke100 variable indicates whether the respondent had smoked at least 100 cigarettes in her lifetime. The other variables record the respondent’s height in inches, weight in pounds as well as their desired weight, wtdesire, age in years, and gender.

# %% [markdown]
# ### Exercise 1
# How many cases are there in this data set? How many variables? For each variable, identify its data type (e.g. categorical, discrete). </div>
#
# We can have a look at the first few entries (rows) of our data with the command

# %%
cdc.head()
# Out:
#      genhlth  exerany  hlthplan  smoke100  height  weight  wtdesire  age  \
# 0       good        0         1         0      70     175       175   77
# 1       good        0         1         1      64     125       115   33
# 2       good        1         1         1      60     105       105   49
# 3       good        1         1         0      66     132       124   42
# 4  very good        0         1         0      61     150       130   55
#
#   gender
# 0      m
# 1      f
# 2      f
# 3      f
# 4      f

# %%
cdc.tail()
# Out:
#          genhlth  exerany  hlthplan  smoke100  height  weight  wtdesire  age  \
# 19995       good        1         1         0      66     215       140   23
# 19996  excellent        0         1         0      73     200       185   35
# 19997       poor        0         1         0      65     216       150   57
# 19998       good        1         1         0      67     165       165   81
# 19999       good        1         1         1      69     170       165   83
#
#       gender
# 19995      f
# 19996      m
# 19997      f
# 19998      f
# 19999      m

# %% [markdown]
# You could also look at all of the data frame at once by typing its name into the console, but that might be unwise here. We know cdc has 20,000 rows, so viewing the entire data set would mean flooding your screen. It’s better to take small peeks at the data with head, tail or the subsetting techniques that you’ll learn in a moment.

# %% [markdown]
# ### Summaries and tables
#
# The BRFSS questionnaire is a massive trove of information. A good first step in any analysis is to distill all of that information into a few summary statistics and graphics. As a simple example, the function describe returns a numerical summary: count, mean, standard deviation, minimum, first quartile, median, second quartile, and maximum. For weight this is

# %%
cdc['weight'].describe()
# Out:
# count    20000.00000
# mean       169.68295
# std         40.08097
# min         68.00000
# 25%        140.00000
# 50%        165.00000
# 75%        190.00000
# max        500.00000
# Name: weight, dtype: float64

# %% [markdown]
# If you wanted to compute the interquartile range for the respondents’ weight, you would look at the output from the summary command above and then enter

# %%
190 - 140
# Out:
# 50

# %% [markdown]
# Python also has built-in functions to compute summary statistics one by one. For instance, to calculate the mean, median, and variance of weight, type

# %%
cdc['weight'].mean()
cdc['weight'].var()
cdc['weight'].median()
# Out:
# 165.0

# %% [markdown]
# While it makes sense to describe a quantitative variable like weight in terms of these statistics, what about categorical data? We would instead consider the sample frequency or relative frequency distribution. The function value_counts does this for you by counting the number of times each kind of response was given. For example, to see the number of people who have smoked 100 cigarettes in their lifetime, type

# %% [markdown]
# ### On Your Own

# %% [markdown]
# ### 1. Make a scatterplot of weight versus desired weight. Describe the relationship between these two variables.

# %%
# import matplotlib mudules to draw plot

import matplotlib.pylab as plt

cdc.plot(kind='scatter', x='weight', y='wtdesire')

# %% [markdown]
# From the plot we can see when the wight increses the wtdesire increses graduately. Most people's weight are between 200 and 300, and people's wtdesire is mainly 100 to 250.

# %% [markdown]
# ### 2. Let’s consider a new variable: the difference between desired weight (wtdesire) and current weight (weight). Create this new variable by subtracting the two columns in the DataFrame and assigning them to a new object called wdiff.

# %%
# create a new object called wdiff
# wdiff equals the difference between desired weight (wtdesire) and current weight (weight)

cdc["wdiff"] = cdc["weight"] - cdc["wtdesire"]
cdc.head()
# Out:
#      genhlth  exerany  hlthplan  smoke100  height  weight  wtdesire  age  \
# 0       good        0         1         0      70     175       175   77
# 1       good        0         1         1      64     125       115   33
# 2       good        1         1         1      60     105       105   49
# 3       good        1         1         0      66     132       124   42
# 4  very good        0         1         0      61     150       130   55
#
#   gender  wdiff
# 0      m      0
# 1      f     10
# 2      f      0
# 3      f      8
# 4      f     20

# %% [markdown]
# ### 3. What type of data is wdiff? If an observation wdiff is 0, what does this mean about the person's weight and desired weight. What if wdiff is positive or negative?

# %%
#use dtype function to get the types of all columns 
cdc.dtypes
# Out:
# genhlth     object
# exerany      int64
# hlthplan     int64
# smoke100     int64
# height       int64
# weight       int64
# wtdesire     int64
# age          int64
# gender      object
# wdiff        int64
# dtype: object

# %% [markdown]
# The type of wdiff is int.  If the wdiff is 0, which means the weight equals the the wtdesire, and person is reaching his\her desire weight. If the wdiff is positive, which means the weight is more than the wtdesire. People need to do more excercise and make a health plan to lose weight. If the wdiff is negative, which means the weight is less than the wtdesire. People need to increase nutrition and have a balanced diet to increase weight.

# %% [markdown]
# ### 4. Describe the distribution of wdiff in terms of its center, shape, and spread, including any plots you use. What does this tell us about how people feel about their current weight?

# %%
# using seaborn library to creates box plots

import seaborn as sns
sns.boxplot(cdc['wdiff'])
plt.show()

# %% [markdown]
# Use the function describe to return a numerical summary for wdiff: count, mean, standard deviation, minimum, first quartile, median, second quartile, and maximum.

# %%
cdc['wdiff'].describe()
# Out:
# count    20000.000000
# mean        14.589100
# std         24.045856
# min       -500.000000
# 25%          0.000000
# 50%         10.000000
# 75%         21.000000
# max        300.000000
# Name: wdiff, dtype: float64

# %%
# from the description of the wdiff, we can compute the the interquartile range for the wdiff 
21-0
# Out:
# 21

# %% [markdown]
# From the boxplot we can confirm that the median and upper and lower quartiles reported in the numerical summary match those in the graph. the interquartile range for the wdiff weight is 21, and the max is 300, the min is -500. and most of wdiff is positive which means People are generally heavier than their desired weight.

# %%
# make a distribution of wdiff to see its center, shape, and spread
cdc['wdiff'].plot(kind = 'hist',edgecolor = 'black', linewidth = 1, bins = 50)
plt.show();

# %% [markdown]
# From this histogram, we can see that the center of wdiff is mainly concentrated on -10 ~ 20 and it's frequency reached to 10000. For the spread, the frequency of wdiff graduately reduced with the value of wdiff increse from 0 to 100 and from 0 to -100. The shape of wdiff is like a Normal distribution curve.

# %% [markdown]
# ### 5. Using numerical summaries and a side-by-side box plot, determine if men tend to view their weight differently than women.

# %%
# use pandas' boxplot() to compare the weights of men and women and see the diffrence

cdc.boxplot(column = 'wdiff', by = 'gender')
plt.show();

cdc.boxplot(column = 'weight', by = 'gender')
plt.show();

# %%
# use describe function to get the summaries data of female

cdc['weight'][cdc['gender'] == 'f'].describe()
# Out:
# count    10431.000000
# mean       151.666187
# std         34.297519
# min         68.000000
# 25%        128.000000
# 50%        145.000000
# 75%        170.000000
# max        495.000000
# Name: weight, dtype: float64

# %%
# use describe function to get the summaries data of female

cdc['weight'][cdc['gender'] == 'm'].describe()
# Out:
# count    9569.000000
# mean      189.322709
# std        36.550355
# min        78.000000
# 25%       165.000000
# 50%       185.000000
# 75%       210.000000
# max       500.000000
# Name: weight, dtype: float64

# %% [markdown]
# From the boxplot we can see that for the male and female tend to view their weight similarly. there is not much difference between them. but male tend to have a large difference of wdiff than female.

# %% [markdown]
# ### 6. Now it’s time to get creative. Find the mean and standard deviation of weight and determine what proportion of the weights are within one standard deviation of the mean.

# %%
#usdescribe to get the data

cdc['weight'].describe()
# Out:
# count    20000.00000
# mean       169.68295
# std         40.08097
# min         68.00000
# 25%        140.00000
# 50%        165.00000
# 75%        190.00000
# max        500.00000
# Name: weight, dtype: float64

# %%
# upper weight value with the standard deviation plus mean 

40 + 169
# Out:
# 209

# %%
# lower weight value with the mean minus standard deviation  

169 - 40
# Out:
# 129

# %%
# get the data that 'weight' is bigger than 129 and 'weight'is  less than 209

within_weights = cdc[(cdc['weight'] > 129) & (cdc['weight'] < 209)]

within_weights.head()
# Out:
#      genhlth  exerany  hlthplan  smoke100  height  weight  wtdesire  age  \
# 0       good        0         1         0      70     175       175   77
# 3       good        1         1         0      66     132       124   42
# 4  very good        0         1         0      61     150       130   55
# 6  very good        1         1         0      71     194       185   31
# 7  very good        0         1         0      67     170       160   45
#
#   gender  wdiff
# 0      m      0
# 3      f      8
# 4      f     20
# 6      m      9
# 7      m     10

# %%
#use function shape to count the number of total people in this data

cdc.shape[0]
# Out:
# 20000

# %%
#use function shape to count the number of people who have the weight within one standard deviation of the mean.

within_weights.shape[0]
# Out:
# 14142

# %%
# use statistics to compute the proportion of the weights within one standard deviation of the mean.

proportion = within_weights.shape[0] / cdc.shape[0]
proportion
# Out:
# 0.7071
